# %%
import geopandas as gpd
import json

# %%
gdf = gpd.GeoDataFrame.from_file('../test_01001.topojson')
gdf
# Out:
#    id                                           geometry
# 0 NaN  POLYGON ((-86.78886 32.31784, -86.78929 32.317...

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf = gpd.GeoDataFrame.from_file('../01001020912.topojson')
gdf
# Out:
#     id STATEFP20 COUNTYFP20 TRACTCE20 BLOCKCE20          GEOID20      NAME20  \
# 0  NaN        01        001    020901      2037  010010209012037  Block 2037
# 1  NaN        01        001    020901      2025  010010209012025  Block 2025
# 2  NaN        01        001    020901      2016  010010209012016  Block 2016
# 3  NaN        01        001    020901      2022  010010209012022  Block 2022
# 4  NaN        01        001    020901      2002  010010209012002  Block 2002
# 5  NaN        01        001    020901      2003  010010209012003  Block 2003
# 6  NaN        01        001    020901      2007  010010209012007  Block 2007
# 7  NaN        01        001    020901      2001  010010209012001  Block 2001
# 8  NaN        01        001    020901      2024  010010209012024  Block 2024
# 9  NaN        01        001    020901      2017  010010209012017  Block 2017
# 10 NaN        01        001    020901      2045  010010209012045  Block 2045
# ...

# %%
gdf.plot()
# Out:
# <AxesSubplot:>
